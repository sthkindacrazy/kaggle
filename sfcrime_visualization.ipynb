# %%
# %pylab inline 
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv("/Users/joohyung/kaggle/sfcrime/train.csv", parse_dates=["Dates"])
print(train.shape)
train.head()
# Out:
# (878049, 9)
#                 Dates        Category                      Descript  \
# 0 2015-05-13 23:53:00        WARRANTS                WARRANT ARREST
# 1 2015-05-13 23:53:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 2 2015-05-13 23:33:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 3 2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# 4 2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
#
#    DayOfWeek PdDistrict      Resolution                    Address  \
# 0  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 1  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 2  Wednesday   NORTHERN  ARREST, BOOKED  VANNESS AV / GREENWICH ST
# 3  Wednesday   NORTHERN            NONE   1500 Block of LOMBARD ST
# 4  Wednesday       PARK            NONE  100 Block of BRODERICK ST
#
#             X          Y
# 0 -122.425892  37.774599
# 1 -122.425892  37.774599
# 2 -122.424363  37.800414
# 3 -122.426995  37.800873
# ...

# %%
figure, ax = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18, 64)

order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

sns.countplot(data=train, y="Category", hue="DayOfWeek", hue_order = order, ax=ax)

# %%
sns.countplot(data=train, x="PdDistrict")

# %%
sns.countplot(data=train, x="DayOfWeek")

# %%
monday = train[train["DayOfWeek"] == "Monday"]
tuesday = train[train["DayOfWeek"] == "Tuesday"]
wednesday = train[train["DayOfWeek"] == "Wednesday"]
thursday = train[train["DayOfWeek"] == "Thursday"]
friday = train[train["DayOfWeek"] == "Friday"]
saturday = train[train["DayOfWeek"] == "Saturday"]
sunday = train[train["DayOfWeek"] == "Sunday"]

# %%
#sns.countplot(data=monday, x="Category")
#sns.countplot(data=tuesday, x="Category")
#sns.countplot(data=wednesday, x="Category")
sns.countplot(data=thursday, x="Category")
#sns.countplot(data=friday, x="Category")
#sns.countplot(data=saturday, x="Category")
#sns.countplot(data=sunday, x="Category")
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar

# %%
cal = calendar()

train["hour"] = pd.to_datetime(train["Dates"]).dt.hour
train["dow"] = pd.to_datetime(train["Dates"]).dt.dayofweek
train["doy"] = pd.to_datetime(train["Dates"]).dt.dayofyear

# %%
#train["hour"]
#train["dow"]
train["doy"]
# Out:
# 0         133
# 1         133
# 2         133
# 3         133
# 4         133
# 5         133
# 6         133
# 7         133
# 8         133
# 9         133
# 10        133
# 11        133
# 12        133
# 13        133
# 14        133
# 15        133
# 16        133
# 17        133
# 18        133
# 19        133
# 20        133
# 21        133
# 22        133
# 23        133
# 24        133
# 25        133
# 26        133
# 27        133
# 28        133
# 29        133
#          ...
# 878019      6
# 878020      6
# 878021      6
# 878022      6
# 878023      6
# 878024      6
# 878025      6
# 878026      6
# 878027      6
# 878028      6
# 878029      6
# 878030      6
# 878031      6
# 878032      6
# 878033      6
# 878034      6
# 878035      6
# 878036      6
# 878037      6
# 878038      6
# 878039      6
# 878040      6
# 878041      6
# 878042      6
# 878043      6
# 878044      6
# 878045      6
# 878046      6
# 878047      6
# 878048      6
# ...

# %%
train.head(5)
# Out:
#                 Dates        Category                      Descript  \
# 0 2015-05-13 23:53:00        WARRANTS                WARRANT ARREST
# 1 2015-05-13 23:53:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 2 2015-05-13 23:33:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 3 2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# 4 2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
#
#    DayOfWeek PdDistrict      Resolution                    Address  \
# 0  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 1  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 2  Wednesday   NORTHERN  ARREST, BOOKED  VANNESS AV / GREENWICH ST
# 3  Wednesday   NORTHERN            NONE   1500 Block of LOMBARD ST
# 4  Wednesday       PARK            NONE  100 Block of BRODERICK ST
#
#             X          Y  hour  dow  doy
# 0 -122.425892  37.774599    23    2  133
# 1 -122.425892  37.774599    23    2  133
# ...

# %%
figure, ax = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18, 64)

sns.countplot(data=train, y="Category", hue="hour")

# %%
sns.countplot(data=train, x="hour")

# %%
sns.countplot(data=train, x="Address")

# %%
sns.countplot(data=train, x="doy")
